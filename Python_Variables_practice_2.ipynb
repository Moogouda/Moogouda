# %% [markdown]
# <a href="https://colab.research.google.com/github/Moogouda/Moogouda/blob/main/Python_Variables_practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = 99.99
quantity = 5
discount = 0.15
totalcost= float(price) * int(quantity) * (1 - float(discount))
totalcost
# Out:
# 424.9575

# %% [markdown]
# 1- Convert **a** to string<br>
#
# 2- convert **b** to int<br>
#
# 3- change last value of **d** to 30<br>
#
# 4- Convert **e** to list<br>
#
# 5- add another value of **f** which is 'gender':'F'<br>
#
# 6- what is the result of adding **a** to **b**?<br>
#
# 7- change first element of **e** to **g**<br>
#
# 8- add [1,2] to **f** with new key 'skills'<br>
#
# 9- add **c** to new key of **f** as 'qoute'<br>
#
# 10- convert **g** to int<br>

# %%
a = 42
b = '3.14'
c = "Hello from the other side"
d = [1,2,3,4,5]
e = (1,2,0,3)
f = {'name': 'Aya', 'Age':26}
g = True

# %%
a = str(a)

# %%
b = "3.14"
b=int(float(b))
b
# Out:
# 3

# %%
d[4] = 30
d
# Out:
# [1, 2, 3, 4, 30]

# %%
e = list(e)

# %%
f['gender'] ='F'

# %%
int(a) + int(b)
# Out:
# 45

# %%
e[0] = g

# %%
f['skills'] = [1,2]

# %%
f['qoute'] = c

# %%
f
# Out:
# {'name': 'Aya',
#  'Age': 26,
#  'skills': [1, 2],
#  'qoute': 'Hello from the other side'}

# %%
int(g)
# Out:
# 1
