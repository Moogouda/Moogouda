# %% [markdown]
# <a href="https://colab.research.google.com/github/Moogouda/Moogouda/blob/main/Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
name = "Mohamed Gouda"
print(name)
# Out:
# Mohamed Gouda

# %% [markdown]
# ** Types of Variables:
#
#
# *   str (string/text)
# *   int (integar/number)
# *   float (float/decimal number)
# *   bool (boolian/T or F)
# *   List item

# %%
type(name)
# Out:
# str

# %% [markdown]
# start with single qaute i should close by same type of qaute single, same for multiple.
#
# any text in between the qautes will be printed , no rules.

# %%
age = 36
print(age)
# Out:
# 36

# %%
type(age)
# Out:
# int

# %%
hieght = 180.5
type(hieght)
# Out:
# float

# %%
age + hieght
# Out:
# 216.5

# %%
is_employee = True
type(is_employee)
# Out:
# bool

# %%
age + is_employee
# Out:
# 37

# %%
int(hieght)
# Out:
# 180

# %%
bool(hieght)
# Out:
# True

# %%
bool(-10.0)
# Out:
# True
