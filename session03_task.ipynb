# %% [markdown]
# <a href="https://colab.research.google.com/github/Moogouda/Python-Coding/blob/main/session03_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Access the first fruit
# - Access the last fruit using negative indexing
# - Get the middle 3 fruits using slicing
# - Get every other fruit starting from index 1
# - Get the last 2 fruits using negative slicing

# %%
fruits = ['watermelon', 'banana', 'kiwi', 'grapes', 'orange']
fruits[0]
# Out:
# 'watermelon'

# %%
fruits[-1]
# Out:
# 'orange'

# %%
fruits[1:4]
# Out:
# ['banana', 'kiwi', 'grapes']

# %%
fruits[1:]
# Out:
# ['banana', 'kiwi', 'grapes', 'orange']

# %%
fruits[-2:]
# Out:
# ['grapes', 'orange']

# %% [markdown]
# - Access the number 5
# - Get the entire second row
# - Get the first column (first element of each row)
# - Get the diagonal elements [1, 5, 9]
# - Replace the number 8 with 80

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
matrix[1][1]
# Out:
# 5

# %%
matrix[1]
# Out:
# [4, 5, 6]

# %%
matrix[0][0]
# Out:
# 1

# %%
matrix[1][0]
# Out:
# 4

# %%
matrix[2][0]
# Out:
# 7

# %%
matrix[2][1]=80
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 80, 9]]

# %% [markdown]
# - Access the student's name
# - Add a new key 'major' with value 'Computer Science'
# - Modify the age to 21
# - Add a new grade 95 to the grades lis

# %%
student = {
    'name': 'Aya',
    'age': 26,
    'grades': [85, 90, 98],
    'is_honor_roll': True
}
student['name']
# Out:
# 'Aya'

# %%
student['major']='computer science'
student
# Out:
# {'name': 'Aya',
#  'age': 26,
#  'grades': [85, 90, 98],
#  'is_honor_roll': True,
#  'major': 'computer science'}

# %%
student['age']=21
student
# Out:
# {'name': 'Aya',
#  'age': 21,
#  'grades': [85, 90, 98],
#  'is_honor_roll': True,
#  'major': 'computer science'}

# %%
grades = [85,90,98]
grades.append(95)
grades
# Out:
# [85, 90, 98, 95]

# %% [markdown]
# - Get the last 3 characters of the value for key 2
# - Get the first character of each product name
# - Try to access key 'smartphones' (observe the error)
# - Create a new dictionary with product names as keys and numbers as values

# %%
inventory = {
    1: 'smartphones',
    2: 'laptops',
    3: 'tablets',
    4: 'headphones'
}
inventory[2][-3:]
# Out:
# 'ops'

# %%
inventory[1][0]
# Out:
# 's'

# %%
inventory[2][0]
# Out:
# 'l'

# %%
inventory[3][0]
# Out:
# 't'

# %%
inventory[4][0]
# Out:
# 'h'

# %%
inventory['smartphones']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4046436726.py in <cell line: 0>()
# ----> 1 inventory['smartphones']
#
# KeyError: 'smartphones'
