# %% [markdown]
# <a href="https://colab.research.google.com/github/Moogouda/Python-Coding/blob/main/split_and_list_functions_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\nSECTION 1: STUDENT GRADE PROCESSING")

# You're a teacher processing student grades and information

student_records = "John|Doe|85|Computer Science|john.doe@university.edu,Mary|Smith|92|Mathematics|mary.smith@university.edu,David|Johnson|78|Physics|david.johnson@university.edu"
individual_students = student_records.split(',')
first_student_data = student_records.split('|')
first_name = first_student_data[0]
last_name = first_student_data[1]
grade = first_student_data[2]
major = first_student_data[3]
email = first_student_data[4]
# Out:
#   File "/tmp/ipython-input-876118846.py", line 9
#     individual_students =
#                           ^
# SyntaxError: invalid syntax

# %%
student_records = "John|Doe|85|Computer Science|john.doe@university.edu,Mary|Smith|92|Mathematics|mary.smith@university.edu,David|Johnson|78|Physics|david.johnson@university.edu"
individual_students = student_records.split(',')
student_records.split(',')
# Out:
# ['John|Doe|85|Computer Science|john.doe@university.edu',
#  'Mary|Smith|92|Mathematics|mary.smith@university.edu',
#  'David|Johnson|78|Physics|david.johnson@university.edu']

# %%
student_records = "John|Doe|85|Computer Science|john.doe@university.edu,Mary|Smith|92|Mathematics|mary.smith@university.edu,David|Johnson|78|Physics|david.johnson@university.edu"
first_student_data = individual_students[0].split("|")
# individual_students.split("|")

# %%
first_student_data[0]
# Out:
# 'John'

# %%
first_student_data[1]
# Out:
# 'Doe'

# %%
first_student_data[2]
# Out:
# '85'

# %%
first_student_data[3]
# Out:
# 'Computer Science'

# %%
first_student_data[4]
# Out:
# 'john.doe@university.edu'
